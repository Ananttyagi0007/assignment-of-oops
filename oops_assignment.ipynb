# %% [markdown]
# **Theory_quesiton**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# 1.what is object oriented programming in python?
# -Ans OOP is a programming approach that organinze software design around objects and classes instead of only functions and logic. An object represents a real world entity having data (attributes) and behavior(methods).
#  OOP is based on four manin principles
#  1. Encapsulation
#  2. Abstraction
#  3. Inheritance
#  4. Polymorphism
#   ex;
#   A car object can have attributes like color and speed and methods like start() and stop().

# %%
'''2. What is a class in OOP?

A class is a blueprint or template used to create objects. It defines the properties and behaviors that objects will have.

Example:'''
class Student:
    name = "Anant"
    age = 20

    def display(self):
        print(self.name)
'''Here student is a class'''
# Out:
# 'Here student is a class'

# %%
'''3. What is an object in OOP?

An object is an instance of a class. It contains actual values of the attributes defined in the class.'''

class student:
    name = "anant"

s1 = student()
print(s1.name)
# Out:
# anant

# %%
'''4. Difference between Abstraction and Encapsulation
Abstraction	                       Encapsulation
Hides implementation details	     Hides data from direct access
Focuses on what an object does	   Focuses on how data is protected
Achieved using abstract classes	   Achieved using private variables and methods
Reduces complexity	               Improves security

Example:

Abstraction: Using a car without knowing engine details.
Encapsulation: Keeping engine data protected. '''
''' 5. What are dunder methods in Python?

 Dunder (Double underscore ) methods are special methods in Python that start and end with double underscores.

  Examples
__str__()
__len__()
__del__()
__call__()

6. Explain inheritance in OOP

 Inheritance allows one class to acquire properties and methods of another class.
  The existing class is called parent class and the new class is called child class.

  Example:

  class Animal:
    def sound(self):
        print("Animal sound")

class Dog(Animal):
    pass

d = Dog()
d.sound()

7. What is polymorphism in OOP?

Polymorphism means one name having multiple forms.

It allows the same method or operator to behave differently depending on the object.

Example:
print(len("anant"))
print(len([1,2,3,4,5]))

The same len() function works differently for different objects.

'''

# %%
'''8. How is encapsulation achieved in Python?

Encapsulation is achieved by restricting direct access to data using private variables.

Example:
class Account:
    def __init__(self, balance):
        self.__balance = 1000
 __balance becomes private and cannot be accessed directly.


 9. What is a constructor in Python?

 A constructor is a special method that runs automatically when and object is created.

 Python constructor
 __init__()

 Example:
class Student:
    def __init__(self,name):
        self.name=name


10. What are class and static methods in Python?
Class Method
A method that works with class variables.

Uses:
@classmethod

Example:

class Student:
    count=0

    @classmethod
    def show(cls):
        print(cls.count)
Static Method

A method that does not depend on class or object data.

Uses:

@staticmethod

# %%
'''11. What is method overloading in Python?

Method overloading means creating multiple methods with the same name but different parameters.
Python does not support traditional overloading like Java, but it can be achieved using default arguments.

Example:

def add(a,b,c=0):
    return a+b+c

12. What is method overriding in OOP?

Method overriding occurs when a child class provides its own implementation of a method already defined in the parent class.
Example:

class Animal:
    def sound(self):
        print("Sound")

class Dog(Animal):
    def sound(self):
        print("Bark")
13. What is a property decorator in Python?

The @property decorator allows a method to be accessed like an attribute.
Example:

class Student:
    @property
    def name(self):
        return self._name

It helps achieve encapsulation.

14. Why is polymorphism important in OOP?

Polymorphism provides:

Flexibility
Code reusability
Easy maintenance
Ability to use same interface for different objects

It makes programs more scalable.

15. What is an abstract class in Python?

An abstract class is a class that cannot be directly instantiated.

It contains abstract methods that must be implemented by child classes.

Example:

from abc import ABC, abstractmethod

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass


16. What are the advantages of OOP?
Object-Oriented Programming (OOP) provides several advantages that make software development easier and more efficient.

Advantages:
Code Reusability – Existing code can be reused through inheritance.
Encapsulation – Protects data by restricting direct access.
Abstraction – Hides unnecessary implementation details and shows only essential features.
Polymorphism – Allows the same interface to perform different tasks.
Modularity – Programs are divided into classes, making them easier to manage.
Easy Maintenance – Changes in one class have minimal impact on other parts of the program.
Scalability – Large projects can be developed and managed more effectively.


17. What is multiple inheritance in Python?
Multiple inheritance is a feature in Python where a class inherits properties and methods from more than one parent class.

Example:
class Father:
    def show_father(self):
        print("Father Class")

class Mother:
    def show_mother(self):
        print("Mother Class")

class Child(Father, Mother):
    pass

c = Child()
c.show_father()
c.show_mother()
Advantages:
Reuses code from multiple classes.
Combines functionalities of different classes.
18. What is the difference between a class variable and an instance variable?
Class Variable	Instance Variable
Shared by all objects of a class.	Unique for each object.
Declared inside the class but outside methods.	Declared inside the constructor (__init__).
Same value for every object unless changed.	Each object can have a different value.
Example:
class Student:
    college = "ABC College"      # Class variable

    def __init__(self, name):
        self.name = name         # Instance variable

s1 = Student("Anant")
s2 = Student("Rahul")

print(s1.college)
print(s2.name)


19. Explain the purpose of __str__() and __repr__() methods in Python.
__str__()
Returns a user-friendly and readable string representation of an object.
Used by the print() function.
Example:
class Student:
    def __str__(self):
        return "Student Object"

s = Student()
print(s)
__repr__()
Returns an official and detailed string representation of an object.
Mainly used for debugging and development.
Example:
class Student:
    def __repr__(self):
        return "Student()"

s = Student()
print(repr(s))
Difference:
__str__()	__repr__()
Human-readable output	Developer/debugging output
Used by print()	Used by repr()
20. What is the significance of the super() function in Python?

The super() function is used to call methods or constructors of the parent class from a child class.

Benefits:
Reuses parent class code.
Avoids rewriting code.
Supports multiple inheritance correctly.
Example:
class Animal:
    def __init__(self):
        print("Animal Constructor")

class Dog(Animal):
    def __init__(self):
        super().__init__()
        print("Dog Constructor")

d = Dog()
21. What is the significance of the __del__() method in Python?

The __del__() method is called automatically when an object is about to be destroyed.

It is known as the destructor.

Uses:
Release resources.
Close files or database connections.
Perform cleanup operations.
Example:
class Test:
    def __del__(self):
        print("Object Destroyed")

t = Test()
del t
22. What is the difference between @staticmethod and @classmethod in Python?
@staticmethod	@classmethod
Does not access class or instance variables.	Can access class variables.
Does not receive self or cls.	Receives cls as the first parameter.
Used for utility functions.	Used for operations related to the class.
Static Method Example:
class Demo:
    @staticmethod
    def greet():
        print("Hello")
Class Method Example:
class Demo:
    count = 10

    @classmethod
    def show(cls):
        print(cls.count)


23. How does polymorphism work in Python with inheritance?
Polymorphism allows a child class to provide its own implementation of a method already defined in the parent class. This is achieved through method overriding.

Example:
class Animal:
    def sound(self):
        print("Animal Sound")

class Dog(Animal):
    def sound(self):
        print("Bark")

class Cat(Animal):
    def sound(self):
        print("Meow")

animals = [Dog(), Cat()]

for animal in animals:
    animal.sound()
Output:
Bark
Meow

The same method (sound()) behaves differently depending on the object.


24. What is method chaining in Python OOP?

Method chaining is a technique where multiple methods are called one after another on the same object.

Each method returns the object itself (self), allowing the next method to be called.
Example:
class Calculator:
    def add(self, x):
        print("Add:", x)
        return self

    def multiply(self, x):
        print("Multiply:", x)
        return self

c = Calculator()
c.add(5).multiply(2)
Advantages:
Makes code shorter and more readable.
Improves code organization


25. What is the purpose of the __call__() method in Python?
The __call__() method allows an object to be called like a function.

When an object is followed by parentheses (), Python automatically executes the __call__() method.
Example:
class Greeting:
    def __call__(self, name):
        print("Hello,", name)

g = Greeting()
g("Anant")
Output:
Hello, Anant
Uses:
Creating callable objects.
Function wrappers and decorators.
Machine Learning models and custom callable classes.'''

# %%
# Parcticle questions

# %%
'''1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
that overrides the speak() method to print "Bark!".'''

class Animal:
    def speak(self):
        print("Generic message")

class Dog(Animal):
    def speak(self):
        print("Bark!")

# %%
from re import M
from IPython.core.display import Math
'''2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
from it and implement the area() method in both.'''
from abc import ABC, abstractmethod
import math

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

c = Circle(5)
r = Rectangle(4, 6)

print("Circle Area:", c.area())
print("Rectangle Area:", r.area())
# Out:
# Circle Area: 78.53981633974483
# Rectangle Area: 24

# %%
'''3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
and further derive a class ElectricCar that adds a battery attribute'''

class Vehicle:
    def __init__(self):
        self.type = "Vehicle"

class Car(Vehicle):
    def __init__(self):
        super().__init__()
        self.brand = "Toyota"

class ElectricCar(Car):
    def __init__(self):
        super().__init__()
        self.battery = "80 kWh"

e = ElectricCar()

print(e.type)
print(e.brand)
print(e.battery)
# Out:
# Vehicle
# Toyota
# 80 kWh

# %%
'''4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
Sparrow and Penguin that override the fly() method. '''

class Bird:
    def fly(self):
        print("Bird can fly")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high.")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly.")

birds = [Sparrow(), Penguin()]

for bird in birds:
    bird.fly()
# Out:
# Sparrow flies high.
# Penguin cannot fly.

# %%
'''5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
balance and methods to deposit, withdraw, and check balance'''

class BankAccount:
    def __init__(self):
        self.__balance = 0

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if self.__balance >= amount:
            self.__balance -= amount
        else:
            print("Insufficient balance")

    def check_balance(self):
        return self.__balance

account = BankAccount()
account.deposit(1000)
account.withdraw(500)
print(account.check_balance())
# Out:
# 500

# %%
'''6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
and Piano that implement their own version of play().'''
class Instrument:
    def play(self):
        print("Playing Instrument")

class Guitar(Instrument):
    def play(self):
        print("Playing Guitar")

class Piano(Instrument):
    def play(self):
        print("Playing Piano")

instruments = [Guitar(), Piano()]

for i in instruments:
    i.play()
# Out:
# Playing Guitar
# Playing Piano

# %%
'''7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
method subtract_numbers() to subtract two numbers'''

class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

print(MathOperations.add_numbers(5, 3))
print(MathOperations.subtract_numbers(5, 3))
# Out:
# 8
# 2

# %%
'''8. Implement a class Person with a class method to count the total number of persons created.'''

class Person:
    count = 0

    def __init__(self):
        Person.count += 1

    @classmethod
    def get_count(cls):
        return cls.count

p1 = Person()
p2 = Person()
print(Person.get_count())
# Out:
# 2

# %%
'''9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
fraction as "numerator/denominator".'''

class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

f = Fraction(3, 4)
print(f)
# Out:
# 3/4

# %%
'''10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
vectors'''
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

v1 = Vector(1, 2)
v2 = Vector(3, 4)
v3 = v1 + v2
print(v3.x, v3.y)
# Out:
# 4 6

# %%
'''11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
{name} and I am {age} years old."'''

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p = Person("Anant", 20)
p.greet()
# Out:
# Hello, my name is Anant and I am 20 years old.

# %%
'''12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
the average of the grades'''
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

s = Student("Anant", [90, 80, 70])
print(s.average_grade())
# Out:
# 80.0

# %%
'''13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
area'''
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0


    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


r = Rectangle()
r.set_dimensions(5, 3)
print(r.area())
# Out:
# 15

# %%
'''14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
and hourly rate. Create a derived class Manager that adds a bonus to the salary'''

class Employee:
    def __init__(self):
        self.hours_worked = 0
        self.hourly_rate = 0

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self):
        super().__init__()
        self.bonus = 0

    def calculate_salary(self):
        return super().calculate_salary() + self.bonus

# %%
'''15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
calculates the total price of the product'''

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# %%
'''16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
implement the sound() method'''

from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo")

class Sheep(Animal):
    def sound(self):
        print("Baa")

# %%
'''17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
returns a formatted string with the book's details'''

class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}\nAuthor: {self.author}\nYear Published: {self.year_published}"

# %%
'''18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
attribute number_of_rooms'''

class House:

    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):

    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

m = Mansion("Delhi", 25000000, 12)

print("Address:", m.address)
print("Price:", m.price)
print("Rooms:", m.number_of_rooms)
# Out:
# Address: Delhi
# Price: 25000000
# Rooms: 12
